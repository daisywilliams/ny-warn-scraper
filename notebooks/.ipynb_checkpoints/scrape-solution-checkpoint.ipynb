# %%
# use the import keyword to import pandas, requests, and bs4 modules
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# %%
# assign the NY WARN notice url to a variable
url = "https://labor.ny.gov/app/warn/default.asp?warnYr=2019"
url
# Out:
# 'https://labor.ny.gov/app/warn/default.asp?warnYr=2019'

# %%
# define headers
headers = {'accept-encoding': 'deflate'}

# %%
# make a get request to the url using the requests library and assign the response to a variable called 'response'
response = requests.get(url, headers=headers)

# %%
# print out status code of response to confirm that your request worked
response.status_code
# Out:
# 200

# %%
# print out the response text
# response.text

# %%
# parse the response text using Beautiful Soup's html parser and assign output to a variable called 'soup'
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# scrape the first table on the page and assign it to a variable called 'table'
table = soup.find("table")

# %%
# grab all rows from the table and assign to a variable called 'rows'
rows = soup.find_all("tr")

# %%
# print out the number of rows — this is how many WARN notices there were in 2019 
len(rows)
# Out:
# 346

# %%
# make an array called 'results'
results = []

# loop through the rows using a for loop
for row in rows:
    # grab the anchor tag (the link tag) in the row and then grab the href attribute from the tag
    a = row.find("a")['href']
    # concatenate the root url from above with this href attribute and assign to a variable called 'company_url'
    company_url = f'{url}{a}'
    print(company_url)
    # make a get request to the company url assign the response to a variable called 'company_response'
    company_response = requests.get(company_url, headers=headers)

    # parse the response text and assign output to a variable called 'company_soup'
    company_soup = BeautifulSoup(company_response.text, 'html.parser')
    #company_soup = BeautifulSoup(BeautifulSoup(company_page, 'html.parser').prettify(formatter=lambda s: s.replace(u'\xa0', '').strip()))
    # grab the first table on the page
    company_table = company_soup.find('table')

#     if not company_table:
#         print(company_response.text)
#         continue


    for span in company_table.find_all('span'):
        span.unwrap()
    
    # loop through all of the p tags
    for p in company_table.find_all('p'):
        text = p.get_text('\n', strip=True)
        if ('Date of Notice:' in text):
            notice_date = text.split(":")[1].strip().split('\n')[0].split()[0].replace(',', '').replace(';', '')
            # print(notice_date)
        elif ('Reason Stated for Filing:' in text):
            reason = text.split(":")[1].strip()
            # print(reason)
        elif ('Company:' in text):
            split_company = text.split('\n')
            company = split_company[1].strip()
            address = " ".join(split_company[2:])
            #print(company)
            #print(address)
        elif ('Phone:' in text):
            phone = text.split(":")[1].strip()
            #print(phone)
        elif ('Business Type:' in text):
            business_type = text.split(":")[1].strip()
            #print(business_type)
        elif ('Number Affected:' in text):
            affected = text.split(":")[1].strip().split()[0].replace(',', '')
            #print(affected)
        elif ('Total Employees:' in text):
            total_employees = text.split(":")[1].strip().split()[0].replace(',', '')
            #print(total_employees)
        elif ('Layoff Date:' in text):
            layoff_date = text.split(":")[1].strip()
            #print(layoff_date)
        elif ('Reason for Dislocation:' in text):
            dislocation = text.split(":")[1].strip()
            #print(dislocation)
        elif ('Union:' in text):
            union = text.split(":")[1].strip()
            #print(union)
        elif ('Classification:' in text):
            classification = text.split(":")[1].strip()
            #print(classification)
    result = {
        'notice_date': notice_date,
        'reason': reason,
        'company': company,
        'address': address,
        'phone': phone,
        'business_type': business_type,
        'affected': affected,
        'total_employees': total_employees,
        'layoff_date': layoff_date,
        'dislocation': dislocation,
        'union': union,
        'classification': classification
     }
    results.append(result)
# Out:
# https://labor.ny.gov/app/warn/default.asp?warnYr=2019details.asp?id=7048
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-48a621ebda43> in <module>
#      23
#      24 # unwrap the spans
# ---> 25     for span in company_table.find_all('span'):
#      26         span.unwrap()
#      27
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
df = pd.DataFrame(results)
df
# Out:
#      notice_date                   reason  \
# 0      3/30/2020   Temporary Plant Layoff
# 1      4/22/2020   Temporary Plant Layoff
# 2      4/23/2020   Temporary Plant Layoff
# 3      2/19/2020             Plant Layoff
# 4       4/9/2020   Temporary Plant Layoff
# ...          ...                      ...
# 1173    1/6/2020            Plant Closing
# 1174  12/27/2019  Temporary Plant Closing
# 1175  12/30/2019            Plant Closing
# 1176  12/30/2019            Plant Closing
# 1177  12/23/2019            Plant Closing
#
#                                                 company  \
# 0                         Peninsula Hotel New York, LLC
# 1                        Deluxe Creative Services, Inc.
# 2                        Deluxe Creative Services, Inc.
# 3                                                  CBRE
# 4                    Slocum Dickson Medical Group, PLLC
# ...                                                 ...
# 1173  Macy's Broadway Mall Store (Macy's Retail Hold...
# 1174                        Wesley Gardens Nursing Home
# 1175  127 W. 43rd St. Chophouse, Inc. (Heartland Bre...
# 1176                New York Express and Logistics, LLC
# 1177  Benchmark Hospitality of Westchester, LLC (Dor...
#
#                                             address           phone  \
# 0                 700 5th Avenue New York, NY 10019  (212) 903-3912
# 1            44 West 18th Street New York, NY 10011  (747) 400-7986
# 2           218 West 18th Street New York, NY 10011  (747) 400-7986
# 3     275 7th Avenue, 17th Floor New York, NY 10011  (214) 438-8850
# 4        1729 Burrstone Road New Hartford, NY 13413  (315) 624-1962
# ...                                             ...             ...
# 1173         100 Broadway Mall Hicksville, NY 11801  (646) 429-7462
# 1174               3 Upton Park Rochester, NY 14607  (585) 241-2105
# 1175        127 West 43rd Street New York, NY 10018  (917) 999-6532
# 1176                 292 Wolf Road Latham, NY 12110  (617) 968-5311
# 1177     975 Anderson Hill Road Rye Brook, NY 10573  (914) 935-6652
#
#                                           business_type affected  \
# 0                                                 Hotel      459
# 1           Visual Effects and Post Production Services       19
# 2           Visual Effects and Post Production Services       66
# 3                       Commercial Real Estate Services       46
# 4                                      Medical Facility       42
# ...                                                 ...      ...
# 1173                                       Retail Store      155
# 1174                                       Nursing Home      132
# 1175                                         Restaurant      106
# 1176  Trucking company providing freight transportat...       48
# 1177                                       Resort Hotel      275
#
#      total_employees                                        layoff_date  \
# 0              -----                                          3/29/2020
# 1              -----                              3/25/2020 – 4/19/2020
# 2              -----                                          3/25/2020
# 3                 57  Separations for 40 employees will occur on 5/2...
# 4              -----  32 employees were separated on 4/3/2020. An ad...
# ...              ...                                                ...
# 1173             155  Macy's Broadway Mall Store employee separation...
# 1174             132  Beginning on 12/31/2019, with all affected emp...
# 1175             106  The layoffs are expected to commence on March ...
# 1176              48                                          3/31/2020
# 1177             275                                          1/12/2020
#
#                                             dislocation  \
# 0     Unforeseeable business circumstances prompted ...
# 1     Unforeseeable business circumstances prompted ...
# 2     Unforeseeable business circumstances prompted ...
# 3     Reduction in workload due to a change in busin...
# 4     Unforeseeable business circumstances prompted ...
# ...                                                 ...
# 1173                                           Economic
# 1174                          Due to a water line break
# 1175                                           Economic
# 1176  Contract between New York Express and Logistic...
# 1177                                    Loss of funding
#
#                                                   union  \
# 0     New York Hotel & Motel Trades Council, AFL-CIO...
# 1          The employees are not represented by a union
# 2          The employees are not represented by a union
# 3         The employees are not represented by a union.
# 4          The employees are not represented by a union
# ...                                                 ...
# 1173      The employees are not represented by a union.
# 1174                                          1199 SEIU
# 1175      The employees are not represented by a union.
# 1176      The employees are not represented by a union.
# 1177      The employees are not represented by a union.
#
#                classification
# 0      Temporary Plant Layoff
# 1      Temporary Plant Layoff
# 2      Temporary Plant Layoff
# 3                Plant Layoff
# 4      Temporary Plant Layoff
# ...                       ...
# 1173            Plant Closing
# 1174  Temporary Plant Closing
# 1175            Plant Closing
# 1176            Plant Closing
# 1177            Plant Closing
#
# [1178 rows x 12 columns]

# %%
df.to_csv('data/warn.csv', index=False)

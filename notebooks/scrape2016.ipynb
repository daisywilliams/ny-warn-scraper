# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = "https://labor.ny.gov/app/warn/default.asp?warnYr=2016"
url
# Out:
# 'https://labor.ny.gov/app/warn/default.asp?warnYr=2016'

# %%
headers = {'accept-encoding': 'deflate'}
headers
# Out:
# {'accept-encoding': 'deflate'}

# %%
response = requests.get(url, headers=headers)
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %%
type(response.text)
# Out:
# str

# %%
soup = BeautifulSoup (response.text, 'html.parser')

# %%
table = soup.find("table")

# %%
rows =soup.find_all("tr")

# %%
len(rows)
# Out:
# 331

# %%
# indicate the url start of the individual case URLs as they aren't the same as the launching page
newurl = "https://labor.ny.gov/app/warn/"

# %%
results = []
for row in rows:
    #print(row)
    a = row.find("a")['href']
    #print(a)
    company_url = f'{newurl}{a}'
    print(company_url)
    company_response = requests.get(company_url, headers=headers)
   # print (company_response.status_code)
    company_soup = BeautifulSoup(company_response.text, 'html.parser') 
   # print(company_soup)
    company_table = company_soup.find("table")
    # print(company_table)
    paragraphs = company_table.find_all("p")
    for p in paragraphs: 
        text=p.get_text('\n')
        if ('Date of Notice:' in text):
            notice_date = text.split(":")[1].strip().split('\n')[0].split()[0].replace(',', '').replace(';', '')
           # print(notice_date)
        elif ('Reason Stated for Filing:' in text):
            reason = text.split(":")[1].strip()
           # print(reason)
        elif ('Company:' in text):
            #split_company = text.split('\n')
           # company = split_company[1].strip()
            address = " ".join(split_company[3:])
            #print(company)
            #print(address)
        elif ('Phone:' in text):
            phone = text.split(":")[1].strip()
            #print(phone)
        elif ('Business Type:' in text):
            business_type = text.split(":")[1].strip()
            #print(business_type)
        elif ('Number Affected:' in text):
            affected = text.split(":")[1].strip().split()[0].replace(',', '')
            #print(affected)
        elif ('Total Employees:' in text):
            total_employees = text.split(":")[1].strip()
            #print(total_employees)
        elif ('Layoff Date:' in text):
            layoff_date = text.split(":")[1].strip()
            #print(layoff_date)
        elif ('Reason for Dislocation:' in text):
            dislocation = text.split(":")[1].strip()
            #print(dislocation)
        elif ('Union:' in text):
            union = text.split(":")[1].strip()
            #print(union)
        elif ('Classification:' in text):
            classification = text.split(":")[1].strip()
            #print(classification)
    result = {
        'notice_date': notice_date,
        'reason': reason,
        'company': company,
        'address': address,
        'phone': phone,
        'business_type': business_type,
        'affected': affected,
        'total_employees': total_employees,
        'layoff_date': layoff_date,
        'dislocation': dislocation,
        'union': union,
        'classification': classification
     }       
    results.append(result) 
    #break
# Out:
# https://labor.ny.gov/app/warn/details.asp?id=5783
# https://labor.ny.gov/app/warn/details.asp?id=5777
# https://labor.ny.gov/app/warn/details.asp?id=5778
# https://labor.ny.gov/app/warn/details.asp?id=5779
# https://labor.ny.gov/app/warn/details.asp?id=5780
# https://labor.ny.gov/app/warn/details.asp?id=5781
# https://labor.ny.gov/app/warn/details.asp?id=5782
# https://labor.ny.gov/app/warn/details.asp?id=5775
# https://labor.ny.gov/app/warn/details.asp?id=5776
# https://labor.ny.gov/app/warn/details.asp?id=5773
# https://labor.ny.gov/app/warn/details.asp?id=5772
# https://labor.ny.gov/app/warn/details.asp?id=5771
# https://labor.ny.gov/app/warn/details.asp?id=5768
# https://labor.ny.gov/app/warn/details.asp?id=5427
# https://labor.ny.gov/app/warn/details.asp?id=5425
# https://labor.ny.gov/app/warn/details.asp?id=5423
# https://labor.ny.gov/app/warn/details.asp?id=5424
# https://labor.ny.gov/app/warn/details.asp?id=5421
# https://labor.ny.gov/app/warn/details.asp?id=5422
# https://labor.ny.gov/app/warn/details.asp?id=5420
# https://labor.ny.gov/app/warn/details.asp?id=5418
# https://labor.ny.gov/app/warn/details.asp?id=5419
# https://labor.ny.gov/app/warn/details.asp?id=5415
# https://labor.ny.gov/app/warn/details.asp?id=5416
# https://labor.ny.gov/app/warn/details.asp?id=5417
# https://labor.ny.gov/app/warn/details.asp?id=5414
# https://labor.ny.gov/app/warn/details.asp?id=5412
# https://labor.ny.gov/app/warn/details.asp?id=5413
# https://labor.ny.gov/app/warn/details.asp?id=5409
# https://labor.ny.gov/app/warn/details.asp?id=5410
# https://labor.ny.gov/app/warn/details.asp?id=5411
# https://labor.ny.gov/app/warn/details.asp?id=5408
# https://labor.ny.gov/app/warn/details.asp?id=5403
# https://labor.ny.gov/app/warn/details.asp?id=5404
# https://labor.ny.gov/app/warn/details.asp?id=5405
# https://labor.ny.gov/app/warn/details.asp?id=5406
# https://labor.ny.gov/app/warn/details.asp?id=5407
# https://labor.ny.gov/app/warn/details.asp?id=5400

# %%
df= pd.DataFrame(results)
df.head()
# Out:
#   notice_date         reason                  company  \
# 0  12/21/2016  Plant Closing  TANF Support Operations
# 1  12/28/2016   Plant Layoff  TANF Support Operations
# 2  12/27/2016  Plant Closing  TANF Support Operations
# 3  12/27/2016  Plant Closing  TANF Support Operations
# 4  12/27/2016  Plant Closing  TANF Support Operations
#
#                                              address           phone  \
# 0   741 Flushing Ave, 3rd and 4th  Floor  Brookly...  (610) 574-5428
# 1   741 Flushing Ave, 3rd and 4th  Floor  Brookly...  (203) 351-3557
# 2   741 Flushing Ave, 3rd and 4th  Floor  Brookly...  (706) 342-6970
# 3   741 Flushing Ave, 3rd and 4th  Floor  Brookly...  (706) 342-6970
# 4   741 Flushing Ave, 3rd and 4th  Floor  Brookly...  (706) 342-6970
#
#                                        business_type affected  \
# 0  Social  services assistance for the State thro...       28
# 1                              Office and R&D Center       15
# 2                                       Retail store      200
# 3                 Retail store and Automotive Center       96
# 4                 Retail store and Automotive Center      105
#
#                                total_employees  \
# 0  40\n (total employees at the two locations)
# 1                                        -----
# 2                                          200
# 3                                           96
# 4                                          105
#
#                                          layoff_date  \
# 0                                          3/31/2017
# 1                                          3/31/2017
# 2  Terminations will occur during the 14-day peri...
# 3  Terminations will occur during the 14-day peri...
# 4  Terminations will occur during the 14-day peri...
#
#                      dislocation  \
# 0  Loss of contractual agreement
# 1   Reorganization of operations
# 2                       Economic
# 3                       Economic
# 4                       Economic
#
#                                                union classification
# 0  The affected  workers are not represented by a...  Plant Closing
# 1  The affected workers are not represented by a ...   Plant Layoff
# 2  The affected workers are not represented by a ...  Plant Closing
# 3  The affected workers are not represented by a ...  Plant Closing
# 4  The affected workers are not represented by a ...  Plant Closing

# %%
df.to_csv('../data/2016.csv', index=False)
